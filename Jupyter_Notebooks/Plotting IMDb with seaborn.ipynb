# %% [markdown]
# ## Plotting IMDb with seaborn
#
# Wir wollen mittels Python und dem Package Seaborn einen Dataset der IMDb visualisieren. Die Daten können von hier bezogen werden:
#
# https://www.imdb.com/interfaces/

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = "https://datasets.imdbws.com/title.ratings.tsv.gz"
imdb = pd.read_csv(url)

# %%
imdb
# Out:
#         tconst\taverageRating\tnumVotes
# 0                  tt0000001\t5.7\t1702
# 1                   tt0000002\t6.1\t210
# 2                  tt0000003\t6.5\t1462
# 3                   tt0000004\t6.2\t123
# 4                  tt0000005\t6.2\t2261
# ...                                 ...
# 1155090               tt9916682\t5.6\t5
# 1155091               tt9916690\t6.6\t5
# 1155092              tt9916720\t6.5\t82
# 1155093              tt9916766\t6.9\t17
# 1155094              tt9916778\t7.5\t27
#
# [1155095 rows x 1 columns]

# %%
# Um die Spalten durch Tabulatoren auftrennen zu lassen, müssen wir 
# den Parameter sep setzen. 
imdb = pd.read_csv(url, sep="\t")

# %%
imdb
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1702
# 1        tt0000002            6.1       210
# 2        tt0000003            6.5      1462
# 3        tt0000004            6.2       123
# 4        tt0000005            6.2      2261
# ...            ...            ...       ...
# 1155090  tt9916682            5.6         5
# 1155091  tt9916690            6.6         5
# 1155092  tt9916720            6.5        82
# 1155093  tt9916766            6.9        17
# 1155094  tt9916778            7.5        27
#
# [1155095 rows x 3 columns]

# %%
imdb.shape
# Out:
# (1155095, 3)

# %%
imdb["averageRating"]
# Out:
# 0          5.7
# 1          6.1
# 2          6.5
# 3          6.2
# 4          6.2
#           ...
# 1155090    5.6
# 1155091    6.6
# 1155092    6.5
# 1155093    6.9
# 1155094    7.5
# Name: averageRating, Length: 1155095, dtype: float64

# %%
imdb.averageRating
# Out:
# 0          5.7
# 1          6.1
# 2          6.5
# 3          6.2
# 4          6.2
#           ...
# 1155090    5.6
# 1155091    6.6
# 1155092    6.5
# 1155093    6.9
# 1155094    7.5
# Name: averageRating, Length: 1155095, dtype: float64

# %%
type(imdb.averageRating)
# Out:
# pandas.core.series.Series

# %%
imdb.averageRating.describe()
# Out:
# count    1.155095e+06
# mean     6.902492e+00
# std      1.399867e+00
# min      1.000000e+00
# 25%      6.100000e+00
# 50%      7.100000e+00
# 75%      7.900000e+00
# max      1.000000e+01
# Name: averageRating, dtype: float64

# %%
# Arithmetisches Mittel
imdb.averageRating.mean()
# Out:
# 6.90249226254078

# %%
# Median (= 50% Percentil)
imdb.averageRating.median()
# Out:
# 7.1

# %%
imdb.describe()
# Out:
#        averageRating      numVotes
# count   1.155095e+06  1.155095e+06
# mean    6.902492e+00  9.538070e+02
# std     1.399867e+00  1.611668e+04
# min     1.000000e+00  5.000000e+00
# 25%     6.100000e+00  9.000000e+00
# 50%     7.100000e+00  2.000000e+01
# 75%     7.900000e+00  7.900000e+01
# max     1.000000e+01  2.394588e+06

# %%
imdb.averageRating.hist()
# Out:
# <AxesSubplot:>

# %%
imdb.averageRating.hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
# %who
# Out:
# imdb	 pd	 plt	 sns	 url

# %%
# Um Grafiken direkt im Jupyter Notebook anzeigen zu lassen.
# Ist i.A. standardmäßig gesetzt. 
# %matplotlib inline

# %%
sns.boxplot(imdb.averageRating)
# Out:
# C:\Users\Katja\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='averageRating'>

# %%
sns.__version__
# Out:
# '0.11.0'

# %%
sns.boxplot(x=imdb.averageRating)
# Out:
# <AxesSubplot:xlabel='averageRating'>

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
sns.boxplot(y=imdb.averageRating)
# Out:
# <AxesSubplot:ylabel='averageRating'>

# %%
sns.boxplot(x=imdb.numVotes)
# Out:
# <AxesSubplot:xlabel='numVotes'>

# %%
sns.boxplot(y=imdb.numVotes)
# Out:
# <AxesSubplot:ylabel='numVotes'>

# %%
sns.violinplot(y=imdb.averageRating)
# Out:
# <AxesSubplot:ylabel='averageRating'>

# %%
violin_plot = sns.violinplot(y=imdb.averageRating, color="red")

# %%
sns.relplot(x=imdb.averageRating, y=imdb.numVotes)

# %%
sns.scatterplot(x=imdb.averageRating, y=imdb.numVotes)
# Out:
# <AxesSubplot:xlabel='averageRating', ylabel='numVotes'>

# %%
# Ein zufälliges Subset aus der Gesamtmenge extrahieren. 
# random_state ist ein beliebig gewählter Startwert, den wir alle gleich setzen, um 
# die gleiche "zufällige" Untermenge zu bekommen
imdb_subsample = imdb.sample(10000, random_state=42)

# %%
imdb_subsample.shape
# Out:
# (10000, 3)

# %%
sns.stripplot(x=imdb_subsample.averageRating)
# Out:
# <AxesSubplot:xlabel='averageRating'>

# %%
# alpha = Transparenz
sns.stripplot(x=imdb_subsample.averageRating, alpha=0.1)
# Out:
# <AxesSubplot:xlabel='averageRating'>

# %%
sns.stripplot(y=imdb_subsample.averageRating, alpha=0.05)
# Out:
# <AxesSubplot:ylabel='averageRating'>

# %%
sns.boxplot(x=imdb_subsample.averageRating)
sns.stripplot(x=imdb_subsample.averageRating, alpha=0.05, color="black")
# Out:
# <AxesSubplot:xlabel='averageRating'>

# %%
sns.swarmplot(y=imdb_subsample.sample(500, random_state=1).averageRating)
# Out:
# <AxesSubplot:ylabel='averageRating'>

# %%
sns.scatterplot(x=imdb_subsample.averageRating, y=imdb_subsample.numVotes)
# Out:
# <AxesSubplot:xlabel='averageRating', ylabel='numVotes'>

# %%
sns.scatterplot(x=imdb.averageRating, y=imdb.numVotes)
# Out:
# <AxesSubplot:xlabel='averageRating', ylabel='numVotes'>

# %%
sns.scatterplot(data=imdb, x="averageRating", y="numVotes")
# Out:
# <AxesSubplot:xlabel='averageRating', ylabel='numVotes'>

# %%
imdb.averageRating * 1000
# Out:
# 0          5700.0
# 1          6100.0
# 2          6500.0
# 3          6200.0
# 4          6200.0
#             ...
# 1155090    5600.0
# 1155091    6600.0
# 1155092    6500.0
# 1155093    6900.0
# 1155094    7500.0
# Name: averageRating, Length: 1155095, dtype: float64

# %%
# mit der Methode apply kann eine Funktion auf alle Werte einer Series angewandt werden
# es wird eine neue Series zurückgegeben, die die Rückgabewerte der Funktionen enthält
def multiply_by_1000(number):
    return "blub" + str(number * 1000)

imdb.averageRating.apply(multiply_by_1000)
# Out:
# 0          blub5700.0
# 1          blub6100.0
# 2          blub6500.0
# 3          blub6200.0
# 4          blub6200.0
#               ...
# 1155090    blub5600.0
# 1155091    blub6600.0
# 1155092    blub6500.0
# 1155093    blub6900.0
# 1155094    blub7500.0
# Name: averageRating, Length: 1155095, dtype: object

# %%
# Lambda Funktionen (Unbenannte Funktionen)
# Lambda ist nur temporär da. 

imdb.averageRating.apply(lambda number: "blub" + str(number * 1000))
# Out:
# 0          blub5700.0
# 1          blub6100.0
# 2          blub6500.0
# 3          blub6200.0
# 4          blub6200.0
#               ...
# 1155090    blub5600.0
# 1155091    blub6600.0
# 1155092    blub6500.0
# 1155093    blub6900.0
# 1155094    blub7500.0
# Name: averageRating, Length: 1155095, dtype: object

# %%
# Wir generieren eine neue Spalte (Series), in der wir unsere Filme in zwei Klassen einteilen.
# Solche, die 20 (der Median) oder mehr Stimmen bekommen haben und solche, 
# die weniger Stimmen bekommen haben.

# %%
imdb_subsample["voting_class"] = imdb_subsample.numVotes.apply(
    lambda number: "more_or_equal_20" if number >= 20 else "less_than_20"
)

# %%
imdb_subsample
# Out:
#             tconst  averageRating  numVotes      voting_class
# 338287   tt0677808            7.7        84  more_or_equal_20
# 1130218  tt9103670            8.0       153  more_or_equal_20
# 946201   tt5250990            8.3       311  more_or_equal_20
# 696851   tt1841495            8.2        24  more_or_equal_20
# 1037127  tt6880606            6.7        12      less_than_20
# ...            ...            ...       ...               ...
# 1120681  tt8880944            7.8       510  more_or_equal_20
# 378521   tt0779254            6.8         9      less_than_20
# 108065   tt0156572            7.0        32  more_or_equal_20
# 293571   tt0574965            7.6         5      less_than_20
# 421593   tt0921387            8.7        66  more_or_equal_20
#
# [10000 rows x 4 columns]

# %%
sns.stripplot(data=imdb_subsample, y="averageRating", x="voting_class", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='voting_class', ylabel='averageRating'>

# %%
sns.boxplot(data=imdb_subsample, y="averageRating", x="voting_class")
# Out:
# <AxesSubplot:xlabel='voting_class', ylabel='averageRating'>
